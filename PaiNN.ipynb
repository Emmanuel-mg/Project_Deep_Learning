# %% [markdown]
# We first need to connect to our drive to clone the GitHub repository

# %%
from google.colab import drive
import os
drive.mount('/content/drive')

# %% [markdown]
# We clone the GitHub repository

# %%
# !git clone https://user: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@github.com/Emmanuel-mg/Project_Deep_Learning.git

# %% [markdown]
# We install PaiNN as a pip package by moving in the PaiNN folder and using pip install . (installing with setup.py)

# %%
os.chdir("/content/Project_Deep_Learning/PaiNN")
# !pip install .

# %% [markdown]
# We install torch_geometric as it is not already installed on Colab

# %%
# !pip install torch_geometric

# %% [markdown]
# We run the main.py file in the repository

# %%
# !python PaiNN/main.py
